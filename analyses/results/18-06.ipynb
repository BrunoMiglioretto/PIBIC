# %%
import itertools
import pandas as pd
import numpy as np

from aeon.datasets.tsc_datasets import multivariate

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../results/results_18-06.csv")
df_properties = pd.read_csv("../../metadata/datasets_properties.csv")

# %%
reps = ['RP', 'MTF', 'GASF', 'GADF', 'FIRTS', 'CWT']
operations = ["sum", "subtraction", "dot_product", "element_wise"]
convolution_algorithm = [np.nan, "MiniRocket", "Rocket"]

# %%
df
# Out:
#                         dataset representation     operation  accuracy  \
# 0     ArticularyWordRecognition            NaN           NaN  0.520000
# 1            AtrialFibrillation            NaN           NaN  0.400000
# 2                  BasicMotions            NaN           NaN  0.575000
# 3                       Cricket            NaN           NaN  0.500000
# 4                 DuckDuckGeese            NaN           NaN  0.120000
# ...                         ...            ...           ...       ...
# 1804         SpokenArabicDigits            CWT   dot_product  0.390632
# 1805         SpokenArabicDigits            CWT   dot_product  0.332879
# 1806         SpokenArabicDigits            CWT  element_wise  0.180991
# 1807         SpokenArabicDigits            CWT  element_wise  0.432924
# 1808         SpokenArabicDigits            CWT  element_wise  0.451569
#
#      convolution_algorithm classification_algorithm
# 0                      NaN                    Ridge
# 1                      NaN                    Ridge
# 2                      NaN                    Ridge
# 3                      NaN                    Ridge
# 4                      NaN                    Ridge
# ...                    ...                      ...
# 1804                Rocket                    Ridge
# 1805            MiniRocket                    Ridge
# 1806                   NaN                    Ridge
# 1807                Rocket                    Ridge
# 1808            MiniRocket                    Ridge
#
# [1809 rows x 6 columns]

# %%
df_properties
# Out:
#                       dataset  train_cases  test_cases  dimensions  length  \
# 0   ArticularyWordRecognition          275         300           9     144
# 1          AtrialFibrillation           15          15           2     640
# 2                BasicMotions           40          40           6     100
# 3       CharacterTrajectories         1422        1436           3     182
# 4                     Cricket          108          72           6    1197
# 5               DuckDuckGeese           60          40        1345     270
# 6                  EigenWorms          128         131           6   17984
# 7                    Epilepsy          137         138           3     206
# 8        EthanolConcentration          261         263           3    1751
# 9                       ERing           30          30           4      65
# 10              FaceDetection         5890        3524         144      62
# 11            FingerMovements          316         100          28      50
# 12      HandMovementDirection          320         147          10     400
# 13                Handwriting          150         850           3     152
# 14                  Heartbeat          204         205          61     405
# 15             JapaneseVowels          270         370          12      29
# 16                     Libras          180         180           2      45
# 17                       LSST         2459        2466           6      36
# 18             InsectWingbeat        30000       20000         200      78
# 19               MotorImagery          278         100          64    3000
# 20                     NATOPS          180         180          24      51
# 21                  PenDigits         7494        3498           2       8
# 22                    PEMS-SF          267         173         963     144
# 23                    Phoneme         3315        3353          11     217
# 24               RacketSports          151         152           6      30
# 25         SelfRegulationSCP1          268         293           6     896
# 26         SelfRegulationSCP2          200         180           7    1152
# 27         SpokenArabicDigits         6599        2199          13      93
# 28              StandWalkJump           12          15           4    2500
# 29        UWaveGestureLibrary          120         320           3     315
#
#     classes
# 0        25
# 1         3
# 2         4
# 3        20
# 4        12
# 5         5
# 6         5
# 7         4
# 8         4
# 9         6
# 10        2
# 11        2
# 12        4
# 13       26
# 14        2
# 15        9
# 16       15
# 17       14
# 18       10
# 19        2
# 20        6
# 21       10
# 22        7
# 23       39
# 24        4
# 25        2
# 26        2
# 27       10
# 28        3
# 29        8

# %% [markdown]
# ## Por dataset

# %%
plt.figure(figsize=(14, 6))
plt.xticks(rotation=90)

sns.boxplot(x="dataset", y="accuracy", data=df)

# for i, day in enumerate(data["day"].unique()):
#     plt.scatter(i, means[day], color="red", label="Mean" if i == 0 else "")

plt.show()

# %% [markdown]
# ## Por representação

# %%
sns.boxplot(x="representation", y="accuracy", data=df)
# Out:
# <Axes: xlabel='representation', ylabel='accuracy'>

# %% [markdown]
# ## Por operação de fusão

# %%
sns.boxplot(x="operation", y="accuracy", data=df)
# Out:
# <Axes: xlabel='operation', ylabel='accuracy'>

# %% [markdown]
# ## Por algoritmo de convolução

# %%
sns.boxplot(x="convolution_algorithm", y="accuracy", data=df)
# Out:
# <Axes: xlabel='convolution_algorithm', ylabel='accuracy'>

# %% [markdown]
# ## Por representação e operação

# %%
plt.figure(figsize=(14, 6))
plt.xticks(rotation=90)

sns.boxplot(x="representation", y="accuracy", hue="operation", data=df)

plt.legend(title='Operation', loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ## Por representação e algoritmo de convolução

# %%
plt.figure(figsize=(14, 6))
plt.xticks(rotation=90)

sns.boxplot(x="representation", y="accuracy", hue="convolution_algorithm", data=df)

plt.legend(title='Algoritmo de convolução', loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ## Por operação e algoritmo de convolução

# %%
plt.figure(figsize=(14, 6))
plt.xticks(rotation=90)

sns.boxplot(x="operation", y="accuracy", hue="convolution_algorithm", data=df)

plt.legend(title='Algoritmo de convolução', loc='upper left', bbox_to_anchor=(1, 1))

plt.show()
